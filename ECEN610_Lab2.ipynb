# %%
import numpy as np
import matplotlib.pyplot as plt

# Define parameters
A = 1  # Amplitude of the cosine wave
f_cos = 2000000  # Frequency of the cosine wave (in Hz)
f_samp = 5000000  # Sampling rate (in Hz), should be >= 2 * f_cos for Nyquist criterion
t_max = 10/f_samp  # Duration of the signal (in seconds)

# Generate the continuous time (high-resolution) time vector
t_continuous = np.linspace(0, t_max, 1000)  # High-resolution time vector
cos_wave = A*np.cos(2 * np.pi * f_cos * t_continuous)  # Continuous cosine wave

# Generate the sampled time vector
t_sampled = np.arange(0, t_max, 1/f_samp)  # Sampled time vector
cos_wave_sampled = A*np.cos(2 * np.pi * f_cos * t_sampled)  # Sampled cosine wave

# Plot both the continuous and sampled signals
plt.figure(figsize=(10, 6))

# Plot the continuous signal
plt.plot(t_continuous, cos_wave, label='Continuous Cosine Wave', color='blue', lw=2)

# Plot the sampled signal
plt.stem(t_sampled, cos_wave_sampled, label='Sampled Cosine Wave', linefmt='red', markerfmt='ro', basefmt=" ")

plt.title('Sampling of a Cosine Wave')
plt.xlabel('Time [seconds]')
plt.ylabel('Amplitude')
plt.legend()
plt.grid(True)

# Show the plot
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# Define parameters
A = 1  # Amplitude of the cosine wave
f_cos = 2000000  # Frequency of the cosine wave (in Hz)
f_samp = 5000000  # Sampling rate (in Hz), should be >= 2 * f_cos for Nyquist criterion
t_max = 10 / f_samp  # Duration of the signal (in seconds)

# Generate the continuous time (high-resolution) time vector
t_continuous = np.linspace(0, t_max, 1000)  # High-resolution time vector
cos_wave = A * np.cos(2 * np.pi * f_cos * t_continuous)  # Continuous cosine wave

# Generate the sampled time vector
t_sampled = np.arange(0, t_max, 1 / f_samp)  # Sampled time vector
cos_wave_sampled = A * np.cos(2 * np.pi * f_cos * t_sampled)  # Sampled cosine wave

# Parameters for Gaussian noise
P_signal = A**2 / 2  # Signal power
SNR_dB = 50  # Desired SNR in dB

# Calculate noise power based on the desired SNR
P_noise = P_signal / (10**(SNR_dB / 10))  # Noise power
sigma = np.sqrt(P_noise)  # Standard deviation of Gaussian noise

# Generate Gaussian noise
noise = np.random.normal(0, sigma, len(cos_wave_sampled))
print(noise)

# Add noise to the sampled wave
cos_wave_sampled_noisy = cos_wave_sampled + noise

# Plot the original continuous and noisy sampled signals
plt.figure(figsize=(10, 6))
plt.plot(t_continuous, cos_wave, label="Original Cosine Wave", color='blue', alpha=0.7)
plt.scatter(t_sampled, cos_wave_sampled, label="Sampled Cosine Wave", color='green', zorder=5)  # Discrete points for sampled wave
plt.plot(t_sampled, cos_wave_sampled_noisy, label="Cosine Wave with Gaussian Noise (SNR = 50 dB)", color='red', alpha=0.7)
plt.xlabel("Time (seconds)")
plt.ylabel("Amplitude")
plt.title("Cosine Wave with Gaussian Noise (SNR = 50 dB)")
plt.legend()
plt.grid(True)
plt.show()
# Out:
# [-0.0009366  -0.00122978 -0.00042946 -0.00197756 -0.0037397   0.00307879
#   0.00244754  0.00143611 -0.00211636 -0.00196528]

# %%
import numpy as np
import matplotlib.pyplot as plt

# Define parameters
A = 1  # Amplitude of the cosine wave
f_cos = 2000000  # Frequency of the cosine wave (in Hz)
f_samp = 5000000  # Sampling rate (in Hz), should be >= 2 * f_cos for Nyquist criterion
t_max = 10 / f_samp  # Duration of the signal (in seconds)
SNR_dB = 50  # Desired SNR in dB

# Generate the continuous time (high-resolution) time vector
t_continuous = np.linspace(0, t_max, 1000)  # High-resolution time vector
cos_wave = A * np.cos(2 * np.pi * f_cos * t_continuous)  # Continuous cosine wave

# Generate the sampled time vector
t_sampled = np.arange(0, t_max, 1 / f_samp)  # Sampled time vector
cos_wave_sampled = A * np.cos(2 * np.pi * f_cos * t_sampled)  # Sampled cosine wave

# Calculate the signal power
P_signal = A**2 / 2

# Calculate the noise power (which is the variance of the Gaussian noise)
P_noise = P_signal / (10**(SNR_dB / 10))

# The variance of the Gaussian noise is equal to the noise power
variance_noise = P_noise
print(variance_noise)

# Generate Gaussian noise with the calculated variance
noise = np.random.normal(0, np.sqrt(variance_noise), len(cos_wave_sampled))
print(noise)

# Add the noise to the sampled cosine wave
cos_wave_sampled_noisy = cos_wave_sampled + noise

# Plot both the continuous and noisy sampled signals
plt.figure(figsize=(10, 6))

# Plot the continuous signal
plt.plot(t_continuous, cos_wave, label='Continuous Cosine Wave', color='blue', lw=2)

# Plot the sampled signal
plt.stem(t_sampled, cos_wave_sampled, label='Sampled Cosine Wave', linefmt='red', markerfmt='ro', basefmt=" ")

# Plot the noisy sampled signal
plt.stem(t_sampled, cos_wave_sampled_noisy, label='Noisy Sampled Cosine Wave', linefmt='green', markerfmt='go', basefmt=" ")

plt.title('Sampling of a Cosine Wave with Gaussian Noise')
plt.xlabel('Time [seconds]')
plt.ylabel('Amplitude')
plt.legend()
plt.grid(True)

# Show the plot
plt.show()
# Out:
# 5e-06
# [ 3.77238875e-04  4.40496508e-05  5.25448371e-06 -2.25192033e-03
#  -6.61362805e-04 -2.98981965e-03 -6.41045095e-04 -1.33212007e-03
#   3.53755461e-03  3.23767199e-03]

# %%
import numpy as np
import matplotlib.pyplot as plt

np.random.seed(100)

# Define parameters
A = 1  # Amplitude of the cosine wave
f_cos = 2000000  # Frequency of the cosine wave (in Hz)
f_samp = 5000000  # Sampling rate (in Hz), should be >= 2 * f_cos for Nyquist criterion
t_max = 20 / f_samp  # Duration of the signal (in seconds)
SNR_dB = 50  # Desired SNR in dB

# Generate the continuous time (high-resolution) time vector
t_continuous = np.linspace(0, t_max, 1000)  # High-resolution time vector
cos_wave = A * np.cos(2 * np.pi * f_cos * t_continuous)  # Continuous cosine wave

# Generate the sampled time vector
t_sampled = np.arange(0, t_max, 1 / f_samp)  # Sampled time vector
cos_wave_sampled = A * np.cos(2 * np.pi * f_cos * t_sampled)  # Sampled cosine wave

# Calculate the signal power
P_signal = A**2 / 2

# Calculate the noise power (which is the variance of the Gaussian noise)
P_noise = P_signal / (10**(SNR_dB / 10))

# The variance of the Gaussian noise is equal to the noise power
variance_noise = P_noise

# Generate Gaussian noise with the calculated variance
noise = np.random.normal(0, np.sqrt(variance_noise), len(cos_wave_sampled))

# Add the noise to the sampled cosine wave
cos_wave_sampled_noisy = cos_wave_sampled + noise

# Compute the FFT of the noisy sampled signal
N = len(cos_wave_sampled_noisy)  # Number of samples
fft_result = np.fft.fft(cos_wave_sampled_noisy)  # Compute FFT of the noisy signal

# Compute the frequency axis for plotting the PSD
freqs = np.fft.fftfreq(N, 1 / f_samp)  # Frequencies corresponding to the FFT result

# Compute the Power Spectral Density (PSD)
psd = np.abs(fft_result) ** 2 / N  # Normalize by N to get the PSD


# Plot both the continuous and noisy sampled signals
plt.figure(figsize=(10, 6))

# Plot the continuous signal
plt.plot(t_continuous, cos_wave, label='Continuous Cosine Wave', color='blue', lw=2)

# Plot the sampled signal
plt.stem(t_sampled, cos_wave_sampled, label='Sampled Cosine Wave', linefmt='red', markerfmt='ro', basefmt=" ")

# Plot the noisy sampled signal
plt.stem(t_sampled, cos_wave_sampled_noisy, label='Noisy Sampled Cosine Wave', linefmt='green', markerfmt='go', basefmt=" ")

plt.title('Sampling of a Cosine Wave with Gaussian Noise')
plt.xlabel('Time [seconds]')
plt.ylabel('Amplitude')
plt.legend()
plt.grid(True)

# Show the plot
plt.show()

# Plot the Power Spectral Density (PSD)
plt.figure(figsize=(10, 6))

# Only plot positive frequencies (due to symmetry of FFT)
positive_freqs = freqs[:N // 2]
positive_psd = psd[:N // 2]
print(positive_psd)

plt.plot(positive_freqs, 10 * np.log10(positive_psd), label="PSD of Noisy Sampled Signal", color='purple')
plt.title("Power Spectral Density (PSD) of Noisy Sampled Signal")
plt.xlabel("Frequency [Hz]")
plt.ylabel("Power Spectral Density [dB/Hz]")
plt.legend()
plt.grid(True)
plt.show()
# Out:
# [1.35450120e-09 3.54937975e-07 7.58094256e-06 2.73830120e-06
#  7.97892157e-07 9.02037073e-06 2.13055200e-06 8.84129826e-07
#  4.99402686e+00 3.54902988e-06]

# %%
import numpy as np
import matplotlib.pyplot as plt

np.random.seed(100)

# Define parameters
A = 1  # Amplitude of the cosine wave
f_cos = 2000000  # Frequency of the cosine wave (in Hz)
f_samp = 5000000  # Sampling rate (in Hz), should be >= 2 * f_cos for Nyquist criterion
t_max = 20 / f_samp  # Duration of the signal (in seconds)
SNR_dB = 50  # Desired SNR in dB

# Generate the continuous time (high-resolution) time vector
t_continuous = np.linspace(0, t_max, 1000)  # High-resolution time vector
cos_wave = A * np.cos(2 * np.pi * f_cos * t_continuous)  # Continuous cosine wave

# Generate the sampled time vector
t_sampled = np.arange(0, t_max, 1 / f_samp)  # Sampled time vector
cos_wave_sampled = A * np.cos(2 * np.pi * f_cos * t_sampled)  # Sampled cosine wave

# Calculate the signal power
P_signal = A**2 / 2

# Calculate the noise power (which is the variance of the Gaussian noise)
P_noise = P_signal / (10**(SNR_dB / 10))

# The variance of the Gaussian noise is equal to the noise power
variance_noise = P_noise

# Generate Gaussian noise with the calculated variance
noise = np.random.normal(0, np.sqrt(variance_noise), len(cos_wave_sampled))

# Add the noise to the sampled cosine wave
cos_wave_sampled_noisy = cos_wave_sampled + noise

# Apply the Hanning window to the noisy signal
hanning_window = np.hanning(len(cos_wave_sampled_noisy))
windowed_signal = cos_wave_sampled_noisy * hanning_window

# Compute the FFT of the windowed noisy sampled signal
N = len(windowed_signal)  # Number of samples
fft_result = np.fft.fft(windowed_signal)  # Compute FFT of the windowed signal

# Compute the frequency axis for plotting the PSD
freqs = np.fft.fftfreq(N, 1 / f_samp)  # Frequencies corresponding to the FFT result

# Compute the Power Spectral Density (PSD)
psd = np.abs(fft_result) ** 2 / N  # Normalize by N to get the PSD

# Plot both the continuous and noisy sampled signals
plt.figure(figsize=(10, 6))

# Plot the continuous signal
plt.plot(t_continuous, cos_wave, label='Continuous Cosine Wave', color='blue', lw=2)

# Plot the sampled signal
plt.stem(t_sampled, cos_wave_sampled, label='Sampled Cosine Wave', linefmt='red', markerfmt='ro', basefmt=" ")

# Plot the noisy sampled signal
plt.stem(t_sampled, cos_wave_sampled_noisy, label='Noisy Sampled Cosine Wave', linefmt='green', markerfmt='go', basefmt=" ")

plt.title('Sampling of a Cosine Wave with Gaussian Noise')
plt.xlabel('Time [seconds]')
plt.ylabel('Amplitude')
plt.legend()
plt.grid(True)

# Show the plot
plt.show()

# Plot the Power Spectral Density (PSD)
plt.figure(figsize=(10, 6))

# Only plot positive frequencies (due to symmetry of FFT)
positive_freqs = freqs[:N // 2]
positive_psd = psd[:N // 2]
print(positive_psd)

# Plot the PSD in dB
plt.plot(positive_freqs, 10 * np.log10(positive_psd), label="PSD of Noisy Sampled Signal with Hanning Window", color='purple')
plt.title("Power Spectral Density (PSD) of Noisy Sampled Signal with Hanning Window")
plt.xlabel("Frequency [Hz]")
plt.ylabel("Power Spectral Density [dB/Hz]")
plt.legend()
plt.grid(True)
plt.show()
# Out:
# [2.76943625e-07 6.42124885e-07 3.91675393e-06 4.47531921e-06
#  1.82274903e-05 7.28753140e-05 4.86002552e-04 3.23397726e-01
#  1.13301126e+00 3.18206141e-01]

# %%
import numpy as np
import matplotlib.pyplot as plt

np.random.seed(100)

# Define parameters
A = 1  # Amplitude of the cosine wave
f_cos = 2000000  # Frequency of the cosine wave (in Hz)
f_samp = 5000000  # Sampling rate (in Hz), should be >= 2 * f_cos for Nyquist criterion
t_max = 20 / f_samp  # Duration of the signal (in seconds)
SNR_dB = 50  # Desired SNR in dB

# Generate the continuous time (high-resolution) time vector
t_continuous = np.linspace(0, t_max, 1000)  # High-resolution time vector
cos_wave = A * np.cos(2 * np.pi * f_cos * t_continuous)  # Continuous cosine wave

# Generate the sampled time vector
t_sampled = np.arange(0, t_max, 1 / f_samp)  # Sampled time vector
cos_wave_sampled = A * np.cos(2 * np.pi * f_cos * t_sampled)  # Sampled cosine wave

# Calculate the signal power
P_signal = A**2 / 2

# Calculate the noise power (which is the variance of the Gaussian noise)
P_noise = P_signal / (10**(SNR_dB / 10))

# The variance of the Gaussian noise is equal to the noise power
variance_noise = P_noise

# Generate Gaussian noise with the calculated variance
noise = np.random.normal(0, np.sqrt(variance_noise), len(cos_wave_sampled))

# Add the noise to the sampled cosine wave
cos_wave_sampled_noisy = cos_wave_sampled + noise

# Apply the Hanning window to the noisy signal
hamming_window = np.hamming(len(cos_wave_sampled_noisy))
windowed_signal = cos_wave_sampled_noisy * hamming_window

# Compute the FFT of the windowed noisy sampled signal
N = len(windowed_signal)  # Number of samples
fft_result = np.fft.fft(windowed_signal)  # Compute FFT of the windowed signal

# Compute the frequency axis for plotting the PSD
freqs = np.fft.fftfreq(N, 1 / f_samp)  # Frequencies corresponding to the FFT result

# Compute the Power Spectral Density (PSD)
psd = np.abs(fft_result) ** 2 / N  # Normalize by N to get the PSD

# Plot both the continuous and noisy sampled signals
plt.figure(figsize=(10, 6))

# Plot the continuous signal
plt.plot(t_continuous, cos_wave, label='Continuous Cosine Wave', color='blue', lw=2)

# Plot the sampled signal
plt.stem(t_sampled, cos_wave_sampled, label='Sampled Cosine Wave', linefmt='red', markerfmt='ro', basefmt=" ")

# Plot the noisy sampled signal
plt.stem(t_sampled, cos_wave_sampled_noisy, label='Noisy Sampled Cosine Wave', linefmt='green', markerfmt='go', basefmt=" ")

plt.title('Sampling of a Cosine Wave with Gaussian Noise')
plt.xlabel('Time [seconds]')
plt.ylabel('Amplitude')
plt.legend()
plt.grid(True)

# Show the plot
plt.show()

# Plot the Power Spectral Density (PSD)
plt.figure(figsize=(10, 6))

# Only plot positive frequencies (due to symmetry of FFT)
positive_freqs = freqs[:N // 2]
positive_psd = psd[:N // 2]
print(positive_psd)

# Plot the PSD in dB
plt.plot(positive_freqs, 10 * np.log10(positive_psd), label="PSD of Noisy Sampled Signal with Hamming Window", color='purple')
plt.title("Power Spectral Density (PSD) of Noisy Sampled Signal with Hamming Window")
plt.xlabel("Frequency [Hz]")
plt.ylabel("Power Spectral Density [dB/Hz]")
plt.legend()
plt.grid(True)
plt.show()
# Out:
# [2.31562780e-07 5.03525561e-07 3.79273913e-06 3.52966604e-06
#  1.49489688e-05 6.20311824e-05 4.10125058e-04 2.73717140e-01
#  1.34108808e+00 2.69281415e-01]

# %%
import numpy as np
import matplotlib.pyplot as plt

np.random.seed(100)

# Define parameters
A = 1  # Amplitude of the cosine wave
f_cos = 2000000  # Frequency of the cosine wave (in Hz)
f_samp = 5000000  # Sampling rate (in Hz), should be >= 2 * f_cos for Nyquist criterion
t_max = 20 / f_samp  # Duration of the signal (in seconds)
SNR_dB = 50  # Desired SNR in dB

# Generate the continuous time (high-resolution) time vector
t_continuous = np.linspace(0, t_max, 1000)  # High-resolution time vector
cos_wave = A * np.cos(2 * np.pi * f_cos * t_continuous)  # Continuous cosine wave

# Generate the sampled time vector
t_sampled = np.arange(0, t_max, 1 / f_samp)  # Sampled time vector
cos_wave_sampled = A * np.cos(2 * np.pi * f_cos * t_sampled)  # Sampled cosine wave

# Calculate the signal power
P_signal = A**2 / 2

# Calculate the noise power (which is the variance of the Gaussian noise)
P_noise = P_signal / (10**(SNR_dB / 10))

# The variance of the Gaussian noise is equal to the noise power
variance_noise = P_noise

# Generate Gaussian noise with the calculated variance
noise = np.random.normal(0, np.sqrt(variance_noise), len(cos_wave_sampled))

# Add the noise to the sampled cosine wave
cos_wave_sampled_noisy = cos_wave_sampled + noise

# Apply the blackman window to the noisy signal
blackman_window = np.blackman(len(cos_wave_sampled_noisy))
windowed_signal = cos_wave_sampled_noisy * blackman_window

# Compute the FFT of the windowed noisy sampled signal
N = len(windowed_signal)  # Number of samples
fft_result = np.fft.fft(windowed_signal)  # Compute FFT of the windowed signal

# Compute the frequency axis for plotting the PSD
freqs = np.fft.fftfreq(N, 1 / f_samp)  # Frequencies corresponding to the FFT result

# Compute the Power Spectral Density (PSD)
psd = np.abs(fft_result) ** 2 / N  # Normalize by N to get the PSD

# Plot both the continuous and noisy sampled signals
plt.figure(figsize=(10, 6))

# Plot the continuous signal
plt.plot(t_continuous, cos_wave, label='Continuous Cosine Wave', color='blue', lw=2)

# Plot the sampled signal
plt.stem(t_sampled, cos_wave_sampled, label='Sampled Cosine Wave', linefmt='red', markerfmt='ro', basefmt=" ")

# Plot the noisy sampled signal
plt.stem(t_sampled, cos_wave_sampled_noisy, label='Noisy Sampled Cosine Wave', linefmt='green', markerfmt='go', basefmt=" ")

plt.title('Sampling of a Cosine Wave with Gaussian Noise')
plt.xlabel('Time [seconds]')
plt.ylabel('Amplitude')
plt.legend()
plt.grid(True)

# Show the plot
plt.show()

# Plot the Power Spectral Density (PSD)
plt.figure(figsize=(10, 6))

# Only plot positive frequencies (due to symmetry of FFT)
positive_freqs = freqs[:N // 2]
positive_psd = psd[:N // 2]
print(positive_psd)

# Plot the PSD in dB
plt.plot(positive_freqs, 10 * np.log10(positive_psd), label="PSD of Noisy Sampled Signal with blackman Window", color='purple')
plt.title("Power Spectral Density (PSD) of Noisy Sampled Signal with blackman Window")
plt.xlabel("Frequency [Hz]")
plt.ylabel("Power Spectral Density [dB/Hz]")
plt.legend()
plt.grid(True)
plt.show()
# Out:
# [1.37980406e-08 1.71615813e-07 9.30333971e-07 1.23971013e-07
#  9.95018243e-07 1.00152953e-06 1.24104225e-02 3.11964793e-01
#  7.95617778e-01 3.12929651e-01]

# %%
import numpy as np
import matplotlib.pyplot as plt

# Define parameters
A = 1  # Amplitude of the analog signal
f_cos = 200000000  # Frequency of the analog cosine wave (in Hz)
f_samp = 400000000  # Sampling rate (in Hz)
t_max = 30/f_cos  # Duration of the sampling window
resolution = 6  # ADC resolution in bits (e.g., 8 bits means 256 levels)

# Generate the continuous time (analog) time vector
t = np.linspace(0, t_max, int(f_samp * t_max), endpoint=False)  # Time vector
analog_signal = A * np.cos(2 * np.pi * f_cos * t)  # Analog cosine signal

# Define the ADC resolution and quantization levels
adc_levels = 2 ** resolution  # Number of levels the ADC can represent
max_value = 1  # Maximum value of the analog signal (scaled to [0,1])

# Quantize the signal:
# 1. Scale the analog signal to the ADC range [0, adc_levels-1].
# 2. Round the signal to the nearest integer using numpy.round.
quantized_signal = np.round(((analog_signal + A) / (2 * A)) * (adc_levels - 1))

# Map the quantized signal back to the ADC range [0, max_value]
quantized_signal_normalized = (quantized_signal / (adc_levels - 1)) * 2 * A - A

# Plot the analog signal and the quantized signal
plt.figure(figsize=(10, 6))

# Plot the original analog signal
plt.plot(t, analog_signal, label='Analog Signal', color='blue', linewidth=2)

# Plot the quantized signal
plt.stem(t, quantized_signal_normalized, label='Quantized Signal (ADC)', linefmt='red', markerfmt='ro', basefmt=" ")

plt.title(f'Analog Signal and Quantized Signal (ADC with {resolution}-bit resolution)')
plt.xlabel('Time [seconds]')
plt.ylabel('Amplitude')
plt.legend()
plt.grid(True)

# Show the plot
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# Define parameters
A = 1  # Amplitude of the analog signal
f_cos = 200000000  # Frequency of the analog cosine wave (in Hz)
f_samp = 410000000  # Sampling rate (in Hz)
t_max = 100 / f_cos  # Duration of the sampling window
resolution = 6  # ADC resolution in bits (e.g., 6 bits means 64 levels)

# Generate the continuous time (analog) time vector
t = np.linspace(0, t_max, int(f_samp * t_max), endpoint=False)  # Time vector
analog_signal = A * np.cos(2 * np.pi * f_cos * t)  # Analog cosine signal

# Define the ADC resolution and quantization levels
adc_levels = 2 ** resolution  # Number of levels the ADC can represent
max_value = 1  # Maximum value of the analog signal (scaled to [0,1])

# Quantize the signal:
# 1. Scale the analog signal to the ADC range [0, adc_levels-1].
# 2. Round the signal to the nearest integer using numpy.round.
quantized_signal = np.round(((analog_signal + A) / (2 * A)) * (adc_levels - 1))
print(quantized_signal)

# Map the quantized signal back to the ADC range [0, max_value]
quantized_signal_normalized = (quantized_signal / (adc_levels - 1)) * 2 * A - A

# Compute the FFT of the quantized signal
N = len(quantized_signal_normalized)  # Number of samples
fft_result = np.fft.fft(quantized_signal_normalized)  # Compute FFT of the quantized signal

# Compute the frequency axis for plotting the PSD
freqs = np.fft.fftfreq(N, 1 / f_samp)  # Frequencies corresponding to the FFT result

# Compute the Power Spectral Density (PSD)
psd = np.abs(fft_result) ** 2 / N  # Normalize by N to get the PSD

# Only plot positive frequencies (due to symmetry of FFT)
positive_freqs = freqs[:N // 2]
positive_psd = psd[:N // 2]
print(positive_psd)


# Avoid log10(0) error by adding a small constant to PSD
positive_psd = np.maximum(positive_psd, 1e-35)  # Clip the PSD to avoid zero values
print(positive_psd)

# Plot the Power Spectral Density (PSD)
plt.figure(figsize=(10, 6))
plt.plot(positive_freqs, 10 * np.log10(positive_psd), label="PSD of Quantized Signal", color='purple')
plt.title("Power Spectral Density (PSD) of Quantized Signal")
plt.xlabel("Frequency [Hz]")
plt.ylabel("Power Spectral Density [dB/Hz]")
plt.legend()
plt.grid(True)
plt.show()
# Out:
# [63.  0. 63.  1. 62.  2. 60.  4. 57.  7. 54. 11. 51. 14. 47. 19. 42. 23.
#  37. 28. 33. 33. 28. 37. 23. 42. 19. 47. 14. 51. 11. 54.  7. 57.  4. 60.
#   2. 62.  1. 63.  0. 63.  0. 63.  1. 62.  2. 60.  4. 57.  7. 54. 11. 51.
#  14. 47. 19. 42. 23. 37. 28. 33. 33. 28. 37. 23. 42. 19. 47. 14. 51. 11.
#  54.  7. 57.  4. 60.  2. 62.  1. 63.  0. 63.  0. 63.  1. 62.  2. 60.  4.
#  57.  7. 54. 11. 51. 14. 47. 19. 42. 23. 37. 28. 33. 33. 28. 37. 23. 42.
#  19. 47. 14. 51. 11. 54.  7. 57.  4. 60.  2. 62.  1. 63.  0. 63.  0. 63.
#   1. 62.  2. 60.  4. 57.  7. 54. 11. 51. 14. 47. 19. 42. 23. 37. 28. 33.
#  33. 28. 37. 23. 42. 19. 47. 14. 51. 11. 54.  7. 57.  4. 60.  2. 62.  1.
#  63.  0. 63.  0. 63.  1. 62.  2. 60.  4. 57.  7. 54. 11. 51. 14. 47. 19.
#  42. 23. 37. 28. 33. 33. 28. 37. 23. 42. 19. 47. 14. 51. 11. 54.  7. 57.
#   4. 60.  2. 62.  1. 63.  0.]
# [2.76533378e-04 8.06508271e-34 4.34353353e-34 2.25690245e-34
#  6.81828729e-36 2.31441748e-05 6.01349598e-34 7.06243184e-35
# ...

# %%
import numpy as np
import matplotlib.pyplot as plt

# Define parameters
A = 1  # Amplitude of the analog signal
f_cos = 200000000  # Frequency of the analog cosine wave (in Hz)
f_samp = 414000000  # Sampling rate (in Hz)
t_max = 30 / f_cos  # Duration of the sampling window
resolution = 6  # ADC resolution in bits (e.g., 6 bits means 64 levels)

# Generate the continuous time (analog) time vector
t = np.linspace(0, t_max, int(f_samp * t_max), endpoint=False)  # Time vector
analog_signal = A * np.cos(2 * np.pi * f_cos * t)  # Analog cosine signal

# Define the ADC resolution and quantization levels
adc_levels = 2 ** resolution  # Number of levels the ADC can represent
max_value = 1  # Maximum value of the analog signal (scaled to [0,1])

# Quantize the signal:
# 1. Scale the analog signal to the ADC range [0, adc_levels-1].
# 2. Round the signal to the nearest integer using numpy.round.
quantized_signal = np.round(((analog_signal + A) / (2 * A)) * (adc_levels - 1
# ...

# %%
import numpy as np
import matplotlib.pyplot as plt

# Define parameters
A = 1  # Amplitude of the analog signal
f_cos = 200000000  # Frequency of the analog cosine wave (in Hz)
f_samp = 414000000  # Sampling rate (in Hz)
t_max = 30 / f_cos  # Duration of the sampling window
resolution = 12  # ADC resolution in bits (e.g., 6 bits means 64 levels)

# Generate the continuous time (analog) time vector
t = np.linspace(0, t_max, int(f_samp * t_max), endpoint=False)  # Time vector
analog_signal = A * np.cos(2 * np.pi * f_cos * t)  # Analog cosine signal

# Define the ADC resolution and quantization levels
adc_levels = 2 ** resolution  # Number of levels the ADC can represent
max_value = 1  # Maximum value of the analog signal (scaled to [0,1])

# Quantize the signal:
# 1. Scale the analog signal to the ADC range [0, adc_levels-1].
# 2. Round the signal to the nearest integer using numpy.round.
quantized_signal = np.round(((analog_signal + A) / (2 * A)) * (adc_levels - 1))

# Map the quantized signal back to the ADC range [0, max_value]
quantized_signal_normalized = (quantized_signal / (adc_levels - 1)) * 2 * A - A

# Create a Hanning window
hanning_window = np.hanning(len(quantized_signal_normalized))

# Apply the Hanning window to the quantized signal
windowed_signal = quantized_signal_normalized * hanning_window

# Compute the FFT of the windowed signal
N = len(windowed_signal)  # Number of samples
fft_result = np.fft.fft(windowed_signal)  # Compute FFT of the windowed signal

# Compute the frequency axis for plotting the PSD
freqs = np.fft.fftfreq(N, 1 / f_samp)  # Frequencies corresponding to the FFT result

# Compute the Power Spectral Density (PSD)
psd = np.abs(fft_result) ** 2 / N  # Normalize by N to get the PSD

# Only plot positive frequencies (due to symmetry of FFT)
positive_freqs = freqs[:N // 2]
positive_psd = psd[:N // 2]
print(positive_psd)

# Avoid log10(0) error by adding a small constant to PSD
positive_psd = np.maximum(positive_psd, 1e-35)  # Clip the PSD to avoid zero values

# Plot the Power Spectral Density (PSD)
plt.figure(figsize=(10, 6))
plt.plot(positive_freqs, 10 * np.log10(positive_psd), label="PSD of Quantized Signal (Windowed)", color='purple')
plt.title("Power Spectral Density (PSD) of Quantized Signal with Hanning Window")
plt.xlabel("Frequency [Hz]")
plt.ylabel("Power Spectral Density [dB/Hz]")
plt.legend()
plt.grid(True)
plt.show()
# Out:
# [2.32534389e-08 1.56921828e-09 5.83310710e-09 7.44088561e-10
#  1.83374408e-08 1.30233988e-08 1.81856952e-08 5.48781530e-09
#  7.11032090e-09 8.13436028e-09 1.21377188e-08 1.11078935e-08
#  4.28325628e-08 3.25091381e-08 2.13873328e-08 6.93379363e-08
#  7.23413604e-08 7.01364364e-08 2.01689599e-07 1.64356887e-07
#  2.59007902e-07 4.45716695e-07 6.54179039e-07 1.27117440e-06
#  1.72210690e-06 4.22920952e-06 9.84668277e-06 3.05387239e-05
#  1.69212325e-04 9.75435964e-01 3.79359790e+00]

# %%
import numpy as np
import matplotlib.pyplot as plt

# Define parameters
A = 1  # Amplitude of the analog signal
f_cos = 200000000  # Frequency of the analog cosine wave (in Hz)
f_samp = 414000000  # Sampling rate (in Hz)
t_max = 100 / f_cos  # Duration of the sampling window
resolution = 12  # ADC resolution in bits (e.g., 6 bits means 64 levels)

# Generate the continuous time (analog) time vector
t = np.linspace(0, t_max, int(f_samp * t_max), endpoint=False)  # Time vector
analog_signal = A * np.cos(2 * np.pi * f_cos * t)  # Analog cosine signal

# Define the ADC resolution and quantization levels
adc_levels = 2 ** resolution  # Number of levels the ADC can represent
max_value = 1  # Maximum value of the analog signal (scaled to [0,1])

# Quantize the signal:
# 1. Scale the analog signal to the ADC range [0, adc_levels-1].
# 2. Round the signal to the nearest integer using numpy.round.
quantized_signal = np.round(((analog_signal + A) / (2 * A)) * (adc_levels - 1))

# Map the quantized signal back to the ADC range [0, max_value]
quantized_signal_normalized = (quantized_signal / (adc_levels - 1)) * 2 * A - A

# Create a Hanning window
hanning_window = np.hanning(len(quantized_signal_normalized))

# Apply the Hanning window to the quantized signal
windowed_signal = quantized_signal_normalized * hanning_window

# Compute the FFT of the windowed signal
N = len(windowed_signal)  # Number of samples
fft_result = np.fft.fft(windowed_signal)  # Compute FFT of the windowed signal

# Compute the frequency axis for plotting the PSD
freqs = np.fft.fftfreq(N, 1 / f_samp)  # Frequencies corresponding to the FFT result

# Compute the Power Spectral Density (PSD)
psd = np.abs(fft_result) ** 2 / N  # Normalize by N to get the PSD

# Only plot positive frequencies (due to symmetry of FFT)
positive_freqs = freqs[:N // 2]
positive_psd = psd[:N // 2]
print(positive_psd)

# Avoid log10(0) error by adding a small constant to PSD
positive_psd = np.maximum(positive_psd, 1e-35)  # Clip the PSD to avoid zero values

# Plot the Power Spectral Density (PSD)
plt.figure(figsize=(10, 6))
plt.plot(positive_freqs, 10 * np.log10(positive_psd), label="PSD of Quantized Signal (Windowed)", color='purple')
plt.title("Power Spectral Density (PSD) of Quantized Signal with Hanning Window")
plt.xlabel("Frequency [Hz]")
plt.ylabel("Power Spectral Density [dB/Hz]")
plt.legend()
plt.grid(True)
plt.show()
# Out:
# [2.32441600e-11 2.15727647e-10 1.28475283e-08 1.98305844e-08
#  2.23683174e-10 6.64572164e-10 1.55422341e-09 8.75727101e-09
#  1.36272197e-08 1.16027842e-08 7.55109717e-09 9.42273851e-09
#  1.23064967e-08 9.63710982e-09 9.47400052e-09 4.01038012e-09
#  1.57327948e-11 6.80454872e-10 4.55769826e-09 1.46808771e-08
#  1.53854924e-08 9.37193991e-09 7.69893163e-09 6.08652706e-11
#  1.36701602e-08 3.32037550e-10 1.55456327e-09 4.76039042e-10
#  4.22946999e-09 1.00872920e-09 1.16406150e-09 4.62126815e-10
#  5.46495435e-10 3.40602069e-09 4.34301540e-09 1.87150927e-08
#  1.59109209e-09 2.97203389e-09 2.39768469e-09 1.08836430e-08
#  2.30949235e-08 2.95711313e-08 2.27959083e-08 1.15164817e-08
#  3.35708645e-09 6.59876420e-11 7.28619060e-09 1.65862285e-09
#  1.72629850e-09 2.50877313e-08 3.11052796e-08 1.42495401e-08
#  8.51526935e-11 8.33756173e-10 6.31872935e-11 1.05205688e-08
#  1.18796843e-08 3.34383636e-09 1.06883780e-08 1.82120004e-09
# ...

# %%
import numpy as np
import matplotlib.pyplot as plt

# Define parameters
A = 1  # Amplitude of the analog signal
f_cos = 200000000  # Frequency of the analog cosine wave (in Hz)
f_samp = 414000000  # Sampling rate (in Hz)
t_max = 30 / f_cos  # Duration of the sampling window
resolution = 12  # ADC resolution in bits (e.g., 6 bits means 64 levels)

# Generate the continuous time (analog) time vector
t = np.linspace(0, t_max, int(f_samp * t_max), endpoint=False)  # Time vector
analog_signal = A * np.cos(2 * np.pi * f_cos * t)  # Analog cosine signal

# Compute Signal Power (Mean Square Value of the Signal)
signal_power = np.mean(analog_signal ** 2)

# Desired SNR in dB
desired_snr_db = 38

# Compute the noise power needed for the desired SNR
noise_power = signal_power / (10 ** (desired_snr_db / 10))

# Generate Gaussian noise with mean 0 and standard deviation sqrt(noise_power)
noise = np.random.normal(0, np.sqrt(noise_power), len(t))  # mean=0, std=sqrt(noise_power)

# Add the Gaussian noise to the analog signal
noisy_signal = analog_signal + noise

# Define the ADC resolution and quantization levels
adc_levels = 2 ** resolution  # Number of levels the ADC can represent
max_value = 1  # Maximum value of the analog signal (scaled to [0,1])

# Quantize the noisy signal:
# 1. Scale the noisy signal to the ADC range [0, adc_levels-1].
# 2. Round the signal to the nearest integer using numpy.round.
quantized_signal = np.round(((noisy_signal + A) / (2 * A)) * (adc_levels - 1))

# Map the quantized signal back to the ADC range [0, max_value]
quantized_signal_normalized = (quantized_signal / (adc_levels - 1)) * 2 * A - A

# Compute the FFT of the quantized signal (no window applied)
N = len(quantized_signal_normalized)  # Number of samples
fft_result = np.fft.fft(quantized_signal_normalized)  # Compute FFT of the quantized signal

# Compute the frequency axis for plotting the PSD
freqs = np.fft.fftfreq(N, 1 / f_samp)  # Frequencies corresponding to the FFT result

# Compute the Power Spectral Density (PSD)
psd = np.abs(fft_result) ** 2 / N  # Normalize by N to get the PSD

# Only plot positive frequencies (due to symmetry of FFT)
positive_freqs = freqs[:N // 2]
positive_psd = psd[:N // 2]
print(positive_psd)

# Avoid log10(0) error by adding a small constant to PSD
positive_psd = np.maximum(positive_psd, 1e-35)  # Clip the PSD to avoid zero values

# Plot the Power Spectral Density (PSD)
plt.figure(figsize=(10, 6))
plt.plot(positive_freqs, 10 * np.log10(positive_psd), label="PSD of Noisy Quantized Signal", color='purple')
plt.title("Power Spectral Density (PSD) of Noisy Quantized Signal")
plt.xlabel("Frequency [Hz]")
plt.ylabel("Power Spectral Density [dB/Hz]")
plt.legend()
plt.grid(True)
plt.show()

# Print SNR for verification
actual_snr_db = 10 * np.log10(signal_power / noise_power)
print(f"Actual SNR of the noisy signal: {actual_snr_db} dB")
# Out:
# [8.54147800e-05 4.55044830e-05 1.00739119e-04 7.00430467e-05
#  1.07117561e-05 1.84814482e-05 5.05923389e-05 2.92847483e-06
#  1.73928843e-04 5.44051086e-05 1.25012800e-05 6.91694026e-05
#  9.39578929e-05 4.96303378e-05 6.46868094e-06 6.22293359e-05
#  4.81282996e-05 8.32493293e-05 4.87311432e-05 4.21325005e-04
#  3.39837759e-04 1.86193203e-04 2.46721167e-05 2.66658663e-05
#  2.42167407e-05 1.54664547e-04 4.11582530e-05 1.40405407e-04
#  1.65342144e-04 5.84651253e-05 1.54916800e+01]
# Actual SNR of the noisy signal: 38.0 dB

# %%
import numpy as np
import matplotlib.pyplot as plt

# Define parameters
A = 1  # Amplitude of the analog signal
f_cos = 200000000  # Frequency of the analog cosine wave (in Hz)
f_samp = 414000000  # Sampling rate (in Hz)
t_max = 100 / f_cos  # Duration of the sampling window
resolution = 12  # ADC resolution in bits (e.g., 6 bits means 64 levels)

# Generate the continuous time (analog) time vector
t = np.linspace(0, t_max, int(f_samp * t_max), endpoint=False)  # Time vector
analog_signal = A * np.cos(2 * np.pi * f_cos * t)  # Analog cosine signal

# Compute Signal Power (Mean Square Value of the Signal)
signal_power = np.mean(analog_signal ** 2)

# Desired SNR in dB
desired_snr_db = 38

# Compute the noise power needed for the desired SNR
noise_power = signal_power / (10 ** (desired_snr_db / 10))

# Generate Gaussian noise with mean 0 and standard deviation sqrt(noise_power)
noise = np.random.normal(0, np.sqrt(noise_power), len(t))  # mean=0, std=sqrt(noise_power)

# Add the Gaussian noise to the analog signal
noisy_signal = analog_signal + noise

# Define the ADC resolution and quantization levels
adc_levels = 2 ** resolution  # Number of levels the ADC can represent
max_value = 1  # Maximum value of the analog signal (scaled to [0,1])

# Quantize the noisy signal:
# 1. Scale the noisy signal to the ADC range [0, adc_levels-1].
# 2. Round the signal to the nearest integer using numpy.round.
quantized_signal = np.round(((noisy_signal + A) / (2 * A)) * (adc_levels - 1))

# Map the quantized signal back to the ADC range [0, max_value]
quantized_signal_normalized = (quantized_signal / (adc_levels - 1)) * 2 * A - A

# Compute the FFT of the quantized signal (no window applied)
N = len(quantized_signal_normalized)  # Number of samples
fft_result = np.fft.fft(quantized_signal_normalized)  # Compute FFT of the quantized signal

# Compute the frequency axis for plotting the PSD
freqs = np.fft.fftfreq(N, 1 / f_samp)  # Frequencies corresponding to the FFT result

# Compute the Power Spectral Density (PSD)
psd = np.abs(fft_result) ** 2 / N  # Normalize by N to get the PSD

# Only plot positive frequencies (due to symmetry of FFT)
positive_freqs = freqs[:N // 2]
positive_psd = psd[:N // 2]
print(positive_psd)

# Avoid log10(0) error by adding a small constant to PSD
positive_psd = np.maximum(positive_psd, 1e-35)  # Clip the PSD to avoid zero values

# Plot the Power Spectral Density (PSD)
plt.figure(figsize=(10, 6))
plt.plot(positive_freqs, 10 * np.log10(positive_psd), label="PSD of Noisy Quantized Signal", color='purple')
plt.title("Power Spectral Density (PSD) of Noisy Quantized Signal")
plt.xlabel("Frequency [Hz]")
plt.ylabel("Power Spectral Density [dB/Hz]")
plt.legend()
plt.grid(True)
plt.show()

# Print SNR for verification
actual_snr_db = 10 * np.log10(signal_power / noise_power)
print(f"Actual SNR of the noisy signal: {actual_snr_db} dB")
# Out:
# [2.15552993e-04 7.67651392e-05 1.43542830e-06 9.40386568e-06
#  9.89835005e-05 1.66084784e-04 3.44774060e-08 3.50106035e-05
#  2.07469132e-04 2.59240806e-05 1.16925191e-04 8.51869985e-05
#  7.49048721e-05 1.13127307e-04 2.76985764e-05 2.97432214e-05
#  2.77841153e-04 2.69916991e-05 1.93612387e-05 1.78955449e-04
#  9.07418853e-06 4.56803572e-05 1.67213736e-04 9.60597550e-05
#  2.16296217e-06 6.69362321e-05 1.64044096e-05 2.25861750e-04
#  1.10985214e-04 3.97646602e-05 6.21272594e-05 1.54875330e-04
#  3.58583683e-06 2.45719617e-05 1.30584658e-04 2.58039377e-05
#  1.04760816e-05 1.08537560e-04 4.22852266e-05 9.38298412e-06
#  4.13377190e-07 1.57841294e-05 4.08592055e-04 2.23563340e-04
#  1.13763877e-04 7.05109735e-06 2.58868660e-04 6.08856076e-06
#  3.26056561e-05 4.01039002e-05 9.48224844e-05 1.21749720e-04
#  2.74161305e-05 8.44122146e-06 6.98140786e-05 1.61875963e-05
#  1.24457144e-04 3.04103854e-04 1.49457560e-04 5.23846562e-05
# ...

# %%
import numpy as np
import matplotlib.pyplot as plt

# Define parameters
A = 1  # Amplitude of the analog signal
f_cos = 200000000  # Frequency of the analog cosine wave (in Hz)
f_samp = 414000000  # Sampling rate (in Hz)
t_max = 30 / f_cos  # Duration of the sampling window
resolution = 12  # ADC resolution in bits (e.g., 6 bits means 64 levels)

# Generate the continuous time (analog) time vector
t = np.linspace(0, t_max, int(f_samp * t_max), endpoint=False)  # Time vector
analog_signal = A * np.cos(2 * np.pi * f_cos * t)  # Analog cosine signal

# Compute Signal Power (Mean Square Value of the Signal)
signal_power = np.mean(analog_signal ** 2)

# Desired SNR in dB
desired_snr_db = 38

# Compute the noise power needed for the desired SNR
noise_power = signal_power / (10 ** (desired_snr_db / 10))

# Generate Gaussian noise with mean 0 and standard deviation sqrt(noise_power)
noise = np.random.normal(0, np.sqrt(noise_power), len(t))  # mean=0, std=sqrt(noise_power)

# Add the Gaussian noise to the analog signal
noisy_signal = analog_signal + noise

# Define the ADC resolution and quantization levels
adc_levels = 2 ** resolution  # Number of levels the ADC can represent
max_value = 1  # Maximum value of the analog signal (scaled to [0,1])

# Quantize the noisy signal:
# 1. Scale the noisy signal to the ADC range [0, adc_levels-1].
# 2. Round the signal to the nearest integer using numpy.round.
quantized_signal = np.round(((noisy_signal + A) / (2 * A)) * (adc_levels - 1))

# Map the quantized signal back to the ADC range [0, max_value]
quantized_signal_normalized = (quantized_signal / (adc_levels - 1)) * 2 * A - A

# Create a Hanning window
hanning_window = np.hanning(len(quantized_signal_normalized))

# Apply the Hanning window to the quantized signal
windowed_signal = quantized_signal_normalized * hanning_window

# Compute the FFT of the windowed signal
N = len(windowed_signal)  # Number of samples
fft_result = np.fft.fft(windowed_signal)  # Compute FFT of the windowed signal

# Compute the frequency axis for plotting the PSD
freqs = np.fft.fftfreq(N, 1 / f_samp)  # Frequencies corresponding to the FFT result

# Compute the Power Spectral Density (PSD)
psd = np.abs(fft_result) ** 2 / N  # Normalize by N to get the PSD

# Only plot positive frequencies (due to symmetry of FFT)
positive_freqs = freqs[:N // 2]
positive_psd = psd[:N // 2]
print(positive_psd)

# Avoid log10(0) error by adding a small constant to PSD
positive_psd = np.maximum(positive_psd, 1e-35)  # Clip the PSD to avoid zero values

# Plot the Power Spectral Density (PSD)
plt.figure(figsize=(10, 6))
plt.plot(positive_freqs, 10 * np.log10(positive_psd), label="PSD of Noisy Quantized Signal (Windowed)", color='purple')
plt.title("Power Spectral Density (PSD) of Noisy Quantized Signal with Hanning Window")
plt.xlabel("Frequency [Hz]")
plt.ylabel("Power Spectral Density [dB/Hz]")
plt.legend()
plt.grid(True)
plt.show()

# Print SNR for verification
actual_snr_db = 10 * np.log10(signal_power / noise_power)
print(f"Actual SNR of the noisy signal: {actual_snr_db} dB")
# Out:
# [6.04874244e-06 8.08590100e-06 1.28459752e-05 2.18244720e-05
#  1.11005092e-04 2.84295140e-04 2.04572702e-04 1.74718013e-04
#  8.40744914e-05 6.24810589e-06 2.29876975e-05 2.55659928e-05
#  2.31528827e-05 4.22631867e-05 2.32722708e-05 3.95908949e-06
#  7.34578934e-06 1.30230793e-05 7.23408571e-05 9.68729141e-05
#  6.97662794e-06 4.38825679e-05 1.57498659e-05 3.79866239e-05
#  1.29782163e-05 3.02931398e-05 1.18068563e-05 1.72869239e-04
#  2.03185122e-05 9.65887843e-01 3.79417690e+00]
# Actual SNR of the noisy signal: 38.0 dB

# %%
import numpy as np
import matplotlib.pyplot as plt

# Define parameters
A = 1  # Amplitude of the analog signal
f_cos = 200000000  # Frequency of the analog cosine wave (in Hz)
f_samp = 414000000  # Sampling rate (in Hz)
t_max = 100 / f_cos  # Duration of the sampling window
resolution = 12  # ADC resolution in bits (e.g., 6 bits means 64 levels)

# Generate the continuous time (analog) time vector
t = np.linspace(0, t_max, int(f_samp * t_max), endpoint=False)  # Time vector
analog_signal = A * np.cos(2 * np.pi * f_cos * t)  # Analog cosine signal

# Compute Signal Power (Mean Square Value of the Signal)
signal_power = np.mean(analog_signal ** 2)

# Desired SNR in dB
desired_snr_db = 38

# Compute the noise power needed for the desired SNR
noise_power = signal_power / (10 ** (desired_snr_db / 10))

# Generate Gaussian noise with mean 0 and standard deviation sqrt(noise_power)
noise = np.random.normal(0, np.sqrt(noise_power), len(t))  # mean=0, std=sqrt(noise_power)

# Add the Gaussian noise to the analog signal
noisy_signal = analog_signal + noise

# Define the ADC resolution and quantization levels
adc_levels = 2 ** resolution  # Number of levels the ADC can represent
max_value = 1  # Maximum value of the analog signal (scaled to [0,1])

# Quantize the noisy signal:
# 1. Scale the noisy signal to the ADC range [0, adc_levels-1].
# 2. Round the signal to the nearest integer using numpy.round.
quantized_signal = np.round(((noisy_signal + A) / (2 * A)) * (adc_levels - 1))

# Map the quantized signal back to the ADC range [0, max_value]
quantized_signal_normalized = (quantized_signal / (adc_levels - 1)) * 2 * A - A

# Create a Hanning window
hanning_window = np.hanning(len(quantized_signal_normalized))

# Apply the Hanning window to the quantized signal
windowed_signal = quantized_signal_normalized * hanning_window

# Compute the FFT of the windowed signal
N = len(windowed_signal)  # Number of samples
fft_result = np.fft.fft(windowed_signal)  # Compute FFT of the windowed signal

# Compute the frequency axis for plotting the PSD
freqs = np.fft.fftfreq(N, 1 / f_samp)  # Frequencies corresponding to the FFT result

# Compute the Power Spectral Density (PSD)
psd = np.abs(fft_result) ** 2 / N  # Normalize by N to get the PSD

# Only plot positive frequencies (due to symmetry of FFT)
positive_freqs = freqs[:N // 2]
positive_psd = psd[:N // 2]
print(positive_psd)

# Avoid log10(0) error by adding a small constant to PSD
positive_psd = np.maximum(positive_psd, 1e-35)  # Clip the PSD to avoid zero values

# Plot the Power Spectral Density (PSD)
plt.figure(figsize=(10, 6))
plt.plot(positive_freqs, 10 * np.log10(positive_psd), label="PSD of Noisy Quantized Signal (Windowed)", color='purple')
plt.title("Power Spectral Density (PSD) of Noisy Quantized Signal with Hanning Window")
plt.xlabel("Frequency [Hz]")
plt.ylabel("Power Spectral Density [dB/Hz]")
plt.legend()
plt.grid(True)
plt.show()

# Print SNR for verification
actual_snr_db = 10 * np.log10(signal_power / noise_power)
print(f"Actual SNR of the noisy signal: {actual_snr_db} dB")
# Out:
# [6.88437154e-08 3.16711490e-05 9.48589052e-05 2.48707144e-06
#  4.38251507e-05 6.19547848e-05 1.21529188e-04 3.69941416e-05
#  4.27646694e-05 1.56391303e-05 3.44143918e-05 4.50406176e-05
#  4.69620364e-06 3.21975506e-05 1.07219166e-04 1.70464043e-05
#  1.59787224e-05 3.68664761e-05 3.26017872e-06 3.36484535e-05
#  3.14043825e-05 1.94258487e-05 1.77239333e-05 1.26007782e-05
#  3.64954570e-05 2.08121853e-05 1.64837786e-05 3.29999513e-05
#  9.60064331e-05 3.60035590e-05 1.32284487e-05 1.01424126e-04
#  1.03527550e-04 4.05314382e-05 5.12374256e-06 3.49451192e-05
#  4.12062650e-05 2.76704677e-05 6.05906732e-05 2.46483170e-05
#  9.35940076e-06 1.78303446e-05 2.43893859e-05 9.85782033e-07
#  3.62143496e-05 6.17928673e-06 1.96642332e-05 1.64726231e-05
#  1.66305704e-05 9.05259334e-05 5.26655383e-05 4.97351343e-05
#  2.66417135e-05 6.14516232e-06 2.71645283e-05 2.66151896e-05
#  5.07746299e-06 9.20519210e-06 3.95785278e-07 3.63034917e-06
# ...

# %%
import numpy as np

# Given PSD values
psd_values = np.array([2.76943625e-07, 6.42124885e-07, 3.91675393e-06, 4.47531921e-06,
 1.82274903e-05, 7.28753140e-05, 4.86002552e-04, 3.23397726e-01,
 1.13301126e+00, 3.18206141e-01])

# Signal Power: Maximum value in the PSD (assumed to be at signal frequency)
signal_power = np.max(psd_values)

# Noise Power: Sum of all PSD values excluding the signal peak
noise_power = np.sum(psd_values) - signal_power

# Calculate SNR in dB
snr = 10 * np.log10(signal_power / noise_power)

print(f"Signal Power: {signal_power}")
print(f"Noise Power: {noise_power}")
print(f"SNR: {snr} dB")
# Out:
# Signal Power: 4.99402686
# Noise Power: 2.7057510829209264e-05
# SNR: 52.66163032905696 dB

# %%
import numpy as np

# Given PSD values
psd_values = np.array([
    6.88437154e-08, 3.16711490e-05, 9.48589052e-05, 2.48707144e-06,
    4.38251507e-05, 6.19547848e-05, 1.21529188e-04, 3.69941416e-05,
    4.27646694e-05, 1.56391303e-05, 3.44143918e-05, 4.50406176e-05,
    4.69620364e-06, 3.21975506e-05, 1.07219166e-04, 1.70464043e-05,
    1.59787224e-05, 3.68664761e-05, 3.26017872e-06, 3.36484535e-05,
    3.14043825e-05, 1.94258487e-05, 1.77239333e-05, 1.26007782e-05,
    3.64954570e-05, 2.08121853e-05, 1.64837786e-05, 3.29999513e-05,
    9.60064331e-05, 3.60035590e-05, 1.32284487e-05, 1.01424126e-04,
    1.03527550e-04, 4.05314382e-05, 5.12374256e-06, 3.49451192e-05,
    4.12062650e-05, 2.76704677e-05, 6.05906732e-05, 2.46483170e-05,
    9.35940076e-06, 1.78303446e-05, 2.43893859e-05, 9.85782033e-07,
    3.62143496e-05, 6.17928673e-06, 1.96642332e-05, 1.64726231e-05,
    1.66305704e-05, 9.05259334e-05, 5.26655383e-05, 4.97351343e-05,
    2.66417135e-05, 6.14516232e-06, 2.71645283e-05, 2.66151896e-05,
    5.07746299e-06, 9.20519210e-06, 3.95785278e-07, 3.63034917e-06,
    4.61072069e-06, 2.18021403e-05, 2.60952995e-05, 3.18209133e-06,
    4.95121077e-06, 1.98984168e-05, 2.56281073e-05, 2.87042813e-05,
    9.64043678e-06, 3.45709413e-05, 3.91002139e-05, 7.96163354e-06,
    2.10078978e-06, 7.07446488e-06, 8.80949463e-06, 4.27937288e-05,
    2.76219384e-05, 5.60496506e-06, 2.01162742e-05, 7.99599308e-05,
    3.72174633e-05, 3.27894631e-05, 8.27205293e-05, 8.72637489e-05,
    6.12751054e-05, 2.35899853e-05, 1.01545914e-05, 2.55231615e-05,
    1.78464593e-05, 5.46724158e-06, 2.51178206e-05, 1.89743143e-06,
    5.62474454e-07, 1.08708948e-05, 1.81184696e-05, 2.49780069e-05,
    2.48651274e-06, 5.30711050e-06, 1.12620680e-04, 3.26316259e+00,
    1.28386089e+01, 3.26493796e+00, 1.61017076e-04
]

)

# Sort the PSD values in descending order
sorted_psd = np.sort(psd_values)[::-1]

# Signal Power: Sum of the top 2 PSD values
signal_power = np.sum(sorted_psd[:4])

# Noise Power: Sum of the remaining PSD values
noise_power = np.sum(sorted_psd[4:])

# Calculate SNR in dB
snr = 10 * np.log10(signal_power / noise_power)

print(f"Signal Power: {signal_power}")
print(f"Noise Power: {noise_power}")
print(f"SNR: {snr} dB")
# Out:
# Signal Power: 19.366870467076
# Noise Power: 0.0030065758491204
# SNR: 38.08987283250095 dB

# %%
import numpy as np
import matplotlib.pyplot as plt

# Define parameters
A = 1  # Amplitude of the analog signal
f_cos = 200000000  # Frequency of the analog cosine wave (in Hz)
f_samp = 607000000  # Sampling rate (in Hz)
t_max = 100 / f_cos  # Duration of the sampling window
resolution = 6  # ADC resolution in bits (e.g., 6 bits means 64 levels)

# Generate the continuous time (analog) time vector
t = np.linspace(0, t_max, int(f_samp * t_max), endpoint=False)  # Time vector
analog_signal = A * np.cos(2 * np.pi * f_cos * t)  # Analog cosine signal

# Define the ADC resolution and quantization levels
adc_levels = 2 ** resolution  # Number of levels the ADC can represent
max_value = 1  # Maximum value of the analog signal (scaled to [0,1])

# Quantize the signal:
# 1. Scale the analog signal to the ADC range [0, adc_levels-1].
# 2. Round the signal to the nearest integer using numpy.round.
quantized_signal = np.round(((analog_signal + A) / (2 * A)) * (adc_levels - 1))
print(quantized_signal)

# Map the quantized signal back to the ADC range [0, max_value]
quantized_signal_normalized = (quantized_signal / (adc_levels - 1)) * 2 * A - A

# Compute the FFT of the quantized signal
N = len(quantized_signal_normalized)  # Number of samples
fft_result = np.fft.fft(quantized_signal_normalized)  # Compute FFT of the quantized signal

# Compute the frequency axis for plotting the PSD
freqs = np.fft.fftfreq(N, 1 / f_samp)  # Frequencies corresponding to the FFT result

# Compute the Power Spectral Density (PSD)
psd = np.abs(fft_result) ** 2 / N  # Normalize by N to get the PSD

# Only plot positive frequencies (due to symmetry of FFT)
positive_freqs = freqs[:N // 2]
positive_psd = psd[:N // 2]
print(positive_psd)


# Avoid log10(0) error by adding a small constant to PSD
positive_psd = np.maximum(positive_psd, 1e-35)  # Clip the PSD to avoid zero values
print(positive_psd)

# Plot the Power Spectral Density (PSD)
plt.figure(figsize=(10, 6))
plt.plot(positive_freqs, 10 * np.log10(positive_psd), label="PSD of Quantized Signal", color='purple')
plt.title("Power Spectral Density (PSD) of Quantized Signal")
plt.xlabel("Frequency [Hz]")
plt.ylabel("Power Spectral Density [dB/Hz]")
plt.legend()
plt.grid(True)
plt.show()
# Out:
# [63. 16. 15. 63. 18. 13. 63. 20. 11. 62. 22. 10. 62. 24.  9. 61. 25.  7.
#  61. 27.  6. 60. 29.  5. 59. 31.  4. 58. 33.  3. 57. 35.  2. 56. 37.  2.
#  55. 39.  1. 53. 41.  1. 52. 43.  0. 50. 45.  0. 49. 46.  0. 47. 48.  0.
#  45. 50.  0. 43. 51.  0. 42. 53.  1. 40. 54.  1. 38. 55.  2. 36. 57.  3.
#  34. 58.  4. 32. 59.  5. 30. 60.  6. 28. 61.  7. 26. 61.  8. 24. 62. 10.
#  22. 62. 11. 20. 63. 12. 19. 63. 14. 17. 63. 16. 15. 63. 17. 14. 63. 19.
#  12. 63. 21. 10. 62. 23.  9. 62. 25.  8. 61. 27.  6. 60. 29.  5. 59. 31.
#   4. 59. 33.  3. 57. 35.  3. 56. 37.  2. 55. 38.  1. 54. 40.  1. 52. 42.
#   0. 51. 44.  0. 49. 46.  0. 48. 48.  0. 46. 49.  0. 44. 51.  0. 42. 52.
#   1. 40. 54.  1. 38. 55.  2. 37. 56.  3. 35. 57.  3. 33. 59.  4. 31. 59.
#   5. 29. 60.  6. 27. 61.  8. 25. 62.  9. 23. 62. 10. 21. 63. 12. 19. 63.
#  14. 17. 63. 15. 16. 63. 17. 14. 63. 19. 12. 63. 20. 11. 62. 22. 10. 62.
#  24.  8. 61. 26.  7. 61. 28.  6. 60. 30.  5. 59. 32.  4. 58. 34.  3. 57.
# ...
